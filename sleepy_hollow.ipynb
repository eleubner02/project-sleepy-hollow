# %%
import pandas as pd
import gridstatus # for data ingestion
import sklearn # for logistic regression
import statsmodels as sm # for ARIMA
import smtplib # for email routing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 2
#       1 import pandas as pd
# ----> 2 import gridstatus # for data ingestion
#       3 import sklearn # for logistic regression
#       4 import statsmodels as sm # for ARIMA
#
# ModuleNotFoundError: No module named 'gridstatus'

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
